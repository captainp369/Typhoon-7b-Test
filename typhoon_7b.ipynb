# %%
# Typhoon-7B: Thai Large Language Model (Pretrained)
# Model Card : https://huggingface.co/scb10x/typhoon-7b

# %%
# install dependencies
# !pip install transformers > 4.34.0
# !pip install sentencepiece
# !pip install accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 7.0 MB/s eta 0:00:00
# ...

# %%
# import
import torch
from transformers import pipeline
import os

# %%
# check version
import transformers
print("transformers version => "+transformers.__version__)
print("torch version => "+torch.__version__)
# Out:
# transformers version => 4.37.2
# torch version => 2.1.0+cu121

# %%
# load model
typhoon_pipeline = pipeline(
                      model="scb10x/typhoon-7b",
                      torch_dtype=torch.bfloat16,
                      trust_remote_code=True,
                      device_map="auto"
                    )
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/595 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.57G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# ...

# %%
def get_response(input):
  typhoon_response = typhoon_pipeline(input,max_new_tokens=500)
  return typhoon_response[0]["generated_text"]

# %%
# Let's have a conversation
prompt = "ช่วยแนะนำสถานที่ท่องเที่ยว10แห่งในจังหวัดเพชรบุรีพร้อมบอกเหตุผล"
print("Typhoon 7b response:\n"+get_response(prompt))
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Typhoon 7b response:
# ช่วยแนะนำสถานที่ท่องเที่ยว10แห่งในจังหวัดเพชรบุรีพร้อมบอกเหตุผลว่าทำไมถึงอยากไปเที่ยวที่นั้น
# 1.น้ำตกห้วยแม่ประจันต์
# น้ำตกห้วยแม่ประจันต์เป็นน้ำตกที่สวยงามมากน้ำตกมีหลายชั้นและน้ำใสมาก
# 2.วัดห้วยมงคล
# วัดห้วยมงคลเป็นวัดที่มีพระพุทธรูปองค์ใหญ่และสวยงามมาก
# 3.เขาวัง
# เขาวังเป็นสถานที่ท่องเที่ยวที่สวยงามมากและเป็นสถานที่ที่เหมาะกับการไปเที่ยวพักผ่อน
# 4.หาดเจ้าสำราญ
# หาดเจ้าสำราญเป็นหาดที่สวยงามมากและเหมาะกับการไปเที่ยวพักผ่อน
# 5.อุทยานแห่งชาติแก่งกระจาน
# อุทยานแห่งชาติแก่งกระจานเป็นอุทยานแห่งชาติที่สวยงามมากและเหมาะกับการไปเที่ยวพักผ่อน
# 6.เขื่อนแก่งกระจาน
# เขื่อนแก่งกระจานเป็นเขื่อนที่สวยงามมากและเหมาะกับการไปเที่ยวพักผ่อน
# 7.น้ำตกป่าละอู
# น้ำตกป่าละอูเป็นน้ำตกที่สวยงามมากและเหมาะกับการไปเที่ยวพักผ่อน
# 8.วัดถ้ำเขาปูน
# วัดถ้ำเขาปูนเป็นวัดที่สวยงามมากและเหมาะกับการไปเที่ยวพักผ่อน
# 9.เขื่อนเพชร
# เขื่อนเพชรเป็นเขื่อนที่สวยงามมากและเหมาะกับการไปเที่ยวพักผ่อน
# ...

# %%
# Test Prompt
test_prompt_1 = "ประเทศไทยมีจังหวัดทั้งหมดกี่จังหวัด และจังหวัดไหนที่มีพื้นที่ใหญ่ที่สุด?"
print("Typhoon 7b response:\n"+get_response(test_prompt_1))
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Typhoon 7b response:
# ประเทศไทยมีจังหวัดทั้งหมดกี่จังหวัด และจังหวัดไหนที่มีพื้นที่ใหญ่ที่สุด?
# - 10 อันดับจังหวัดที่มีประชากรหนาแน่นที่สุดในประเทศไทย
# - 10 อันดับจังหวัดที่มีประชากรน้อยที่สุดในประเทศไทย
# - 10 อันดับจังหวัดที่มีประชากรมากที่สุดในประเทศไทย
# - 10 อันดับจังหวัดที่มีประชากรน้อยที่สุดในประเทศไทย
# - 10 อันดับจังหวัดที่มีประชากรหนาแน่นที่สุดในประเทศไทย
# - 10 อันดับจังหวัดที่มีประชากรหนาแน่นที่สุดในประเทศไทย
# - 10 อันดับจังหวัดที่มีประชากรหนาแน่นที่สุดในประเทศไทย
# - 10 อันดับจังหวัดที่มีประชากรหนาแน่นที่สุดในประเทศไทย
# - 10 อันดับจังหวัดที่มีประชากรหนาแน่นที่สุดในประเทศไทย
# - 10 อันดับจังหวัดที่มีประชากรหนาแน่นที่สุดในประเทศไทย
# - 10 อันดับจังหวัดที่มีประชากรหนาแน่นที่สุดในประเทศไทย
# - 10 อันดับจังหวัดที่มีประชากรหนาแน่นที่สุดในประเทศไทย
# - 10 อันดับจังหวัดที่มีประชากรหนาแน่นที่สุดในประเทศไทย
# - 10 อันดับจังหวัดที่มีประชากรหนาแน่นที่สุดในประเทศไทย
# ...

# %%
# Test Prompt
test_prompt_1_5 = "ช่วยบอกจำนวนจังหวัดทั้งหมดของประเทศไทย"
print("Typhoon 7b response:\n"+get_response(test_prompt_1_5))
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Typhoon 7b response:
# ช่วยบอกจำนวนจังหวัดทั้งหมดของประเทศไทย
# - 16:00, 10 มิถุนายน 2563 ต่าง ประวัติ +1,000 จังหวัดปทุมธานี →สถานที่ท่องเที่ยว
# - 15:59, 10 มิถุนายน 2563 ต่าง ประวัติ +1,000 จังหวัดปทุมธานี →สถานที่ท่องเที่ยว
# - 15:58, 10 มิถุนายน 2563 ต่าง ประวัติ +1,000 จังหวัดปทุมธานี →สถานที่ท่องเที่ยว
# - 15:57, 10 มิถุนายน 2563 ต่าง ประวัติ +1,000 จังหวัดปทุมธานี →สถานที่ท่องเที่ยว
# - 15:56, 10 มิถุนายน 2563 ต่าง ประวัติ +1,000 จังหวัดปทุมธานี →สถานที่ท่องเที่ยว
# - 15:55, 10 มิถุนายน 2563 ต่าง ประวัติ +1,000 จังหวัดปทุมธานี →สถานที่ท่องเที่ยว
# - 15:54, 10 มิถุนายน 2563 ต่าง ประวัติ +1,000 จังหวัดปทุมธานี →สถานที่ท่องเที่ยว
# - 15:53, 10 มิถุนายน 2563 ต่าง ประวัติ +1,000 จังหวัดปทุมธานี →สถานที่ท่องเที่ยว
# - 15:52, 10 มิถุนายน 2563 ต่าง ประวัติ +1,000 จังหวัดปทุมธานี →สถานที่ท่องเที่ยว
# - 15:51, 10 มิถุนายน 2563 ต่าง ประวัติ +1,000 จังหวัดปทุมธานี →สถานที่ท่องเที่ยว
# ...

# %%
# Test Prompt
test_prompt_2 = "เขียนเรื่องสั้นเกี่ยวกับนักเดินทางที่ได้พบกับป่ามหัศจรรย์ในจังหวัดเชียงใหม่ที่มีต้นไม้สามารถพูดคุยได้"
print("Typhoon 7b response:\n"+get_response(test_prompt_2))
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Typhoon 7b response:
# เขียนเรื่องสั้นเกี่ยวกับนักเดินทางที่ได้พบกับป่ามหัศจรรย์ในจังหวัดเชียงใหม่ที่มีต้นไม้สามารถพูดคุยได้ และได้พบกับชายหนุ่มที่ชื่อว่า “ก้อง” ที่ได้พาเขาไปพบกับความลับของป่าแห่งนี้
# เรื่องราวของ “ก้อง” จะเป็นอย่างไร และความลับของป่าแห่งนี้คืออะไร ติดตามได้ใน “ก้อง” นักเดินทางในป่ามหัศจรรย์
# ติดตามชมซีรีส์ชุด นักเขียนญี่ปุ่นหัวใจเก๋า (Japan Writers) ในวันเสาร์ที่ 10 ก.ย. 65 เวลา 22.05 - 23.00 น. ทางไทยพีบีเอส รับชมทีวีออนไลน์ทาง www.thaipbs.or.th/Live ▼ กำลังโหลดข้อมูล... ▼
# แสดงความคิดเห็น
# กระทู้ที่คุณอาจสนใจ
# อยากทราบว่ามีใครเคยใช้ครีมของแบรนด์นี้บ้างคะ
# อยากทราบว่ามีใครเคยใช้ครีมของแบรนด์นี้บ้างคะ แล้วผลเป็นยังไงบ้างคะ
# ครีมกันแดดของแบรนด์ไหนดีคะ
# อยากได้ครีมกันแดดที่กันแดดได้ดีและไม่ทำให้หน้ามันค่ะ
# ครีมกันแดดของแบรนด์ไหนดีคะ
# อยากได้ครีมกันแดดที่กันแดดได้ดีและไม่ทำให้หน้ามันค่ะ
# ครีมกันแดดของแบรนด์ไหนดีคะ
# อยากได้ครีมกันแดดที่กันแดดได้ดีและไม่ทำให้หน้ามันค่ะ
# ...

# %%
# Test Prompt
test_prompt_3 = "อธิบายประเพณีลอยกระทง รวมถึงประวัติความเป็นมา และความสำคัญของประเพณีนี้ในวัฒนธรรมไทย"
print("Typhoon 7b response:\n"+get_response(test_prompt_3))
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Typhoon 7b response:
# อธิบายประเพณีลอยกระทง รวมถึงประวัติความเป็นมา และความสำคัญของประเพณีนี้ในวัฒนธรรมไทย
# - 10.00 น. ชมการแสดงศิลปวัฒนธรรมไทย
# - 11.00 น. ชมการแสดงศิลปวัฒนธรรมไทย
# - 12.00 น. ชมการแสดงศิลปวัฒนธรรมไทย
# - 13.00 น. ชมการแสดงศิลปวัฒนธรรมไทย
# - 14.00 น. ชมการแสดงศิลปวัฒนธรรมไทย
# - 15.00 น. ชมการแสดงศิลปวัฒนธรรมไทย
# - 16.00 น. ชมการแสดงศิลปวัฒนธรรมไทย
# - 17.00 น. ชมการแสดงศิลปวัฒนธรรมไทย
# - 18.00 น. ชมการแสดงศิลปวัฒนธรรมไทย
# - 19.00 น. ชมการแสดงศิลปวัฒนธรรมไทย
# - 20.00 น. ชมการแสดงศิลปวัฒนธรรมไทย
# - 21.00 น. ชมการแสดงศิลปวัฒนธรรมไทย
# - 22.00 น. ชมการแสดงศิลปวัฒนธรรมไทย
# - 23.00 น. ชมการแสดงศิลปวัฒนธรรมไทย
# - 00.00 น. ชมการแสดงศิลปวัฒนธรรมไทย
# - 01.00 น. ชมการแสดงศิลปวัฒนธรรมไทย
# - 02.00 น. ชมการแสดงศิลปวัฒนธรรมไทย
# - 03.00 น. ชมการแสดงศิลปวัฒนธรรมไทย
# - 04.00 น. ชมการแสดงศิลปวัฒนธรรมไทย
# - 05.00 น. ชมการแสดงศิลปวัฒนธรรมไทย
# - 06.00 น. ชมการแสดงศิลปวัฒนธรรมไทย
# ...

# %%
# Test Prompt
test_prompt_3 = "ช่วยอธิบายประเพณีลอยกระทง และประวัติความเป็นมาหน่อยได้ไหม?"
print("Typhoon 7b response:\n"+get_response(test_prompt_3))
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Typhoon 7b response:
# ช่วยอธิบายประเพณีลอยกระทง และประวัติความเป็นมาหน่อยได้ไหม?
# ...
